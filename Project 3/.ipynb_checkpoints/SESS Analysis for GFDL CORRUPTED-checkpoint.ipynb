# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
obs = pd.read_csv('../Resources/observed_onset.csv')
all_obs = obs[obs['OBS_PHASE'] == 'all']
neutral_obs = obs[obs['OBS_PHASE'] == 'neutral']
all_obs = obs[obs['OBS_PHASE'] == 'all']

all_mean_obs = pd.read_csv('../Resources/all_mean_obs.csv')
neutral_mean_obs = pd.read_csv('../Resources/neutral_mean_obs.csv')
all_mean_obs = pd.read_csv('../Resources/all_mean_obs.csv')

gfdl_all_mean = pd.read_csv('../Resources/gfdl_all_mean.csv')
gfdl_neutral_mean = pd.read_csv('../Resources/gfdl_neutral_mean.csv')
gfdl_all_mean = pd.read_csv('../Resources/gfdl_all_mean.csv')


gfdl_all_onset_mean= pd.read_csv('../Resources/gfdl_all_onset_mean.csv')
gfdl_all_onset_mean= pd.read_csv('../Resources/gfdl_neutral_onset_mean.csv')
gfdl_all_onset_mean= pd.read_csv('../Resources/gfdl_all_onset_mean.csv')
gfdl_all_onset = pd.read_csv('../Resources/gfdl_all_onset.csv')
gfdl_all_onset = pd.read_csv ('../Resources/gfdl_neutral_onset.csv')
gfdl_all_onset= pd.read_csv('../Resources/gfdl_all_onset.csv')

#import model LDC data
gfdl = pd.read_csv('../Resources/GFDL_SPEAR_FULL_LDC.csv')
gfdl_stat = pd.read_csv('../Resources/gfdl_stat.csv')
nasa = pd.read_csv('../Resources/NASA_GEOSS2S_FULL_LDC.csv')
canada = pd.read_csv('../Resources/CanSIPS_IC4_FULL_LDC.csv')
canada['LDC_SST_CanSIPS_IC4'] = canada['LDC_SST_CanSIPS_IC4'] - 273.15
canada['LDC_SST_CanSIPS_IC4_ONETWO'] = canada['LDC_SST_CanSIPS_IC4_ONETWO'] - 273.15
canada['LDC_SST_CanSIPS_IC4_THREE'] = canada['LDC_SST_CanSIPS_IC4_THREE'] - 273.15
canada['LDC_SST_CanSIPS_IC4_FOUR'] = canada['LDC_SST_CanSIPS_IC4_FOUR'] - 273.15
ncep = pd.read_csv('../Resources/NCEP_CFSv2_FULL_LDC.csv')
cola = pd.read_csv('../Resources/COLA_CESM1_FULL_LDC.csv')

#import model LDC data for canadian sisters
canesm = pd.read_csv('../Resources/CanESM5_FULL_LDC.csv')
canesm['LDC_SST_CanESM5'] = canesm['LDC_SST_CanESM5'] - 273.15
canesm['LDC_SST_CanESM5_ONETWO'] = canesm['LDC_SST_CanESM5_ONETWO'] - 273.15
canesm['LDC_SST_CanESM5_THREE'] = canesm['LDC_SST_CanESM5_THREE'] - 273.15
canesm['LDC_SST_CanESM5_FOUR'] = canesm['LDC_SST_CanESM5_FOUR'] - 273.15
nemo = pd.read_csv('../Resources/GEM52_NEMO_FULL_LDC.csv')
nemo['LDC_SST_GEM52_NEMO'] = nemo['LDC_SST_GEM52_NEMO'] - 273.15
nemo['LDC_SST_GEM52_NEMO_ONETWO'] = nemo['LDC_SST_GEM52_NEMO_ONETWO'] - 273.15
nemo['LDC_SST_GEM52_NEMO_THREE'] = nemo['LDC_SST_GEM52_NEMO_THREE'] - 273.15
nemo['LDC_SST_GEM52_NEMO_FOUR'] = nemo['LDC_SST_GEM52_NEMO_FOUR'] - 273.15

#manage obs
obs.rename(columns={'YR': 'year', 'MON': 'month', 'DAY': 'day'}, inplace=True)
# Combine year, month, and day into a single datetime column
obs['TAR'] = pd.to_datetime(obs[['year', 'month', 'day']])
obs = obs[['TAR', 'OBS_NINO3.4_L3', 'OBS_PHASE']]
obs_dict = obs.set_index('TAR')['OBS_NINO3.4_L3'].to_dict()

#input method: 1993 JAS -> yr = 1993, mon = 8, day = 15
all_onset_1 = {"year" : 1991, "month" : 6, "day" : 15}
all_onset_2 = {"year" : 1994, "month" : 9, "day" : 15}
all_onset_3 = {"year" : 1997, "month" : 5, "day" : 15}
all_onset_4 = {"year" : 2002, "month" : 6, "day" : 15}
all_onset_5 = {"year" : 2004, "month" : 7, "day" : 15}
all_onset_6 = {"year" : 2006, "month" : 9, "day" : 15}
all_onset_7 = {"year" : 2009, "month" : 7, "day" : 15}
all_onset_8 = {"year" : 2014, "month" : 10, "day" : 15}
all_onset_9 = {"year" : 2018, "month" : 9, "day" : 15}
#all_onset_10 = {"year" : 2023, "month" : 5, "day" : 15}
all_onsets = [all_onset_1, all_onset_2, all_onset_3,
               all_onset_4, all_onset_5, all_onset_6,
               all_onset_7, all_onset_8, all_onset_9,
               ]

all_onset_1 = {"year" : 1995, "month" : 8, "day" : 15}
all_onset_2 = {"year" : 1998, "month" : 7, "day" : 15}
all_onset_3 = {"year" : 2005, "month" : 11, "day" : 15}
all_onset_4 = {"year" : 2007, "month" : 6, "day" : 15}
all_onset_5 = {"year" : 2008, "month" : 11, "day" : 15}
all_onset_6 = {"year" : 2010, "month" : 6, "day" : 15}
all_onset_7 = {"year" : 2011, "month" : 7, "day" : 15}
all_onset_8 = {"year" : 2016, "month" : 8, "day" : 15}
all_onset_9 = {"year" : 2017, "month" : 10, "day" : 15}
all_onset_10 = {"year" : 2020, "month" : 8, "day" : 15}
all_onsets = [all_onset_1, all_onset_2, all_onset_3,
               all_onset_4, all_onset_5, all_onset_6,
               all_onset_7, all_onset_8, all_onset_9,
               all_onset_10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[180], line 10
#       7 neutral_obs = obs[obs['OBS_PHASE'] == 'neutral']
#       8 all_obs = obs[obs['OBS_PHASE'] == 'all']
# ---> 10 all_mean_obs = pd.read_csv('../Resources/all_mean_obs.csv')
#      11 neutral_mean_obs = pd.read_csv('../Resources/neutral_mean_obs.csv')
#      12 all_mean_obs = pd.read_csv('../Resources/all_mean_obs.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Resources/all_mean_obs.csv'

# %%
def gfdl_onset_finder(dict):

    gfdl_temp = gfdl.copy()

    # Query the DataFrame
    gfdl_onset = gfdl_temp[
        (gfdl_temp['TAR'].dt.year == dict["year"]) &
        (gfdl_temp['TAR'].dt.month == dict["month"]) &
        (gfdl_temp['TAR'].dt.day == dict["day"])
    ]
    return gfdl_onset
    
gfdl['MON'] = pd.to_datetime(gfdl['MON'], format = '%H%M %d %b %Y')
gfdl['START'] = gfdl['MON'].dt.month
gfdl['TARGET'] = ((gfdl['START'] + gfdl['L']).astype(int))%12
gfdl['TARGET'] = gfdl['TARGET'].apply(lambda x: 12 if x == 0 else x)
gfdl['TAR'] = gfdl.apply(lambda row: pd.to_datetime(f"{row['MON'].year}-{row['TARGET']:02d}-15"), axis=1)
gfdl['TAR'] = gfdl.apply(lambda row: row['TAR'].replace(year=row['TAR'].year + 1) if row['TAR'].month < row['MON'].month else row['TAR'], axis=1)
month_to_season = {
    1: 'DJF', 2: 'JFM', 3: 'FMA', 4: 'MAM', 5: 'AMJ', 6: 'MJJ',
    7: 'JJA', 8: 'JAS', 9: 'ASO', 10: 'SON', 11: 'OND', 12: 'NDJ'
}
gfdl['SZN'] = gfdl['TARGET'].map(month_to_season)
gfdl = gfdl[['L', 'MON', 'SZN', 'TAR', 'LDC_SST_GFDL_SPEAR']]
gfdl = gfdl.copy()

# Map the OBS_NINO3.4_L3 values from the dictionary to the gfdl DataFrame
gfdl.loc[:, 'OBS_NINO3.4_L3'] = gfdl['TAR'].map(obs_dict)

gfdl_all_onset_dfs = {}
gfdl_all_onset_dfs = {}
j = 1
for i in all_onsets:
    gfdl_all_onset_dfs[f'{j}'] = gfdl_onset_finder(i)
    j += 1

gfdl_all_onset = pd.concat([gfdl_all_onset_dfs[key] for key in gfdl_all_onset_dfs.keys()], ignore_index=True)

j = 1
for i in all_onsets:
    gfdl_all_onset_dfs[f'{j}'] = gfdl_onset_finder(i)
    j += 1

gfdl_all_onset = pd.concat([gfdl_all_onset_dfs[key] for key in gfdl_all_onset_dfs.keys()], ignore_index=True)

gfdl_all_onset = pd.concat([gfdl_all_onset,gfdl_all_onset], ignore_index=True)

gfdl_all_onset_mean

# %%
gfdl_onset_finder(all_onset_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 gfdl_onset_finder(all_onset_1)
#
# NameError: name 'all_onset_1' is not defined

# %%
gfdl_all_onset
# Out:
#         L        MON  SZN        TAR      SESS  LDC_SST_GFDL_SPEAR  \
# 0    10.5 1994-10-01  JAS 1995-08-15  0.980809            25.66215
# 1     9.5 1994-11-01  JAS 1995-08-15  0.994139            25.52513
# 2     8.5 1994-12-01  JAS 1995-08-15  0.986260            25.48767
# 3     7.5 1995-01-01  JAS 1995-08-15  0.687731            25.26264
# 4     6.5 1995-02-01  JAS 1995-08-15  0.702273            25.25708
# ..    ...        ...  ...        ...       ...                 ...
# 180   5.5 2018-04-01  ASO 2018-09-15  0.790188            26.28632
# 181   4.5 2018-05-01  ASO 2018-09-15  0.694985            26.27201
# 182   3.5 2018-06-01  ASO 2018-09-15  0.979141            26.61941
# 183   2.5 2018-07-01  ASO 2018-09-15  0.964408            27.05198
# 184   1.5 2018-08-01  ASO 2018-09-15  0.999787            27.09763
#
#      MEAN_SST_GFDL_SPEAR  ANOM_GFDL_SPEAR  OBS_NINO3.4_L3  \
# 0              26.115971        -0.453821       26.396667
# 1              26.142254        -0.617124       26.396667
# 2              26.135664        -0.647994       26.396667
# 3              26.245908        -0.983268       26.396667
# 4              26.230352        -0.973272       26.396667
# ..                   ...              ...             ...
# 180            26.208824         0.077496       27.250000
# 181            26.278687        -0.006677       27.250000
# 182            26.261756         0.357654       27.250000
# 183            26.396788         0.655192       27.250000
# 184            26.597937         0.499693       27.250000
#
#      MEAN_OBS_NINO3.4_L3  ANOM_OBS  VARIANCE3.4_L3
# 0              26.955667 -0.559000        0.576438
# 1              26.955667 -0.559000        0.576438
# 2              26.955667 -0.559000        0.576438
# 3              26.955667 -0.559000        0.576438
# 4              26.955667 -0.559000        0.576438
# ..                   ...       ...             ...
# 180            26.763333  0.486667        0.797956
# 181            26.763333  0.486667        0.797956
# 182            26.763333  0.486667        0.797956
# 183            26.763333  0.486667        0.797956
# 184            26.763333  0.486667        0.797956
#
# [185 rows x 12 columns]

# %%
monthly_obs = pd.read_csv('../Resources/monthly_obs.csv')
monthly_obs
# Out:
#     MON  NINO1+2_L3   NINO3_L3  NINO3.4_L3   NINO4_L3  SZN  VARIANCE1+2_L3  \
# 0     2   25.717667  26.422444   26.859889  28.279111  JFM        0.633224
# 1     3   26.041222  27.063111   27.284667  28.381778  FMA        0.687875
# 2     4   25.479778  27.345222   27.678333  28.621556  MAM        0.969434
# 3     5   24.358667  27.150444   27.826222  28.837556  AMJ        1.243217
# 4     6   23.166333  26.558444   27.651111  28.928111  MJJ        1.278459
# 5     7   22.029889  25.847444   27.291667  28.885333  JJA        1.215305
# 6     8   21.230444  25.274778   26.955667  28.816111  JAS        1.155230
# 7     9   20.918111  25.000333   26.763333  28.770111  ASO        1.097573
# 8    10   21.135889  24.995222   26.712556  28.739667  SON        1.217331
# 9    11   21.832889  25.104667   26.672667  28.665667  OND        1.309250
# 10   12   23.010222  25.322111   26.598889  28.500333  NDJ        1.201736
# 11    1   24.495222  25.772667   26.648667  28.370222  DJF        0.822973
#
#     VARIANCE3_L3  VARIANCE3.4_L3  VARIANCE4_L3
# 0       0.722083        0.911147      0.602424
# 1       0.438982        0.569984      0.483076
# 2       0.314258        0.338432      0.351696
# 3       0.300520        0.256750      0.272307
# 4       0.356976        0.281245      0.238351
# 5       0.489432        0.401165      0.252990
# 6       0.671820        0.576438      0.303363
# 7       0.879021        0.797956      0.397474
# 8       1.143673        1.057599      0.521443
# 9       1.366630        1.304206      0.646976
# 10      1.389889        1.402310      0.710849
# 11      1.095406        1.230987      0.681446

# %%
# Create a MultiIndex series from gfdl_stat
multi_index_stat = gfdl_stat.set_index(['L', 'SZN'])['MEAN_SST_GFDL_SPEAR']

# Map the MEAN_SST_GFDL_SPEAR values to the gfdl_all_onset dataframe
gfdl_all_onset['MEAN_SST_GFDL_SPEAR'] = gfdl_all_onset.set_index(['L', 'SZN']).index.map(multi_index_stat)

# Reset index to keep original structure
gfdl_all_onset.reset_index(drop=True, inplace=True)

#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_GFDL_SPEAR'] = gfdl_all_onset['LDC_SST_GFDL_SPEAR'] - gfdl_all_onset['MEAN_SST_GFDL_SPEAR']


# Create a MultiIndex series from gfdl_stat
multi_index_stat_two = monthly_obs.set_index(['SZN'])['NINO3.4_L3']
gfdl_all_onset['MEAN_OBS_NINO3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_two)
gfdl_all_onset.reset_index(drop=True, inplace=True)
#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_OBS'] = gfdl_all_onset['OBS_NINO3.4_L3'] - gfdl_all_onset['MEAN_OBS_NINO3.4_L3']


multi_index_stat_three = monthly_obs.set_index(['SZN'])['VARIANCE3.4_L3']
gfdl_all_onset['VARIANCE3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_three)
gfdl_all_onset.reset_index(drop=True, inplace=True)


gfdl_all_onset['SESS'] = 1-((gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])*(gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])/(gfdl_all_onset['VARIANCE3.4_L3']))


gfdl_all_onset = gfdl_all_onset[['L', 'MON', 'SZN','TAR','SESS','LDC_SST_GFDL_SPEAR','MEAN_SST_GFDL_SPEAR', 'ANOM_GFDL_SPEAR', 'OBS_NINO3.4_L3', 'MEAN_OBS_NINO3.4_L3', 'ANOM_OBS', 'VARIANCE3.4_L3']]

gfdl_all_onset
# Out:
#         L        MON  SZN        TAR      SESS  LDC_SST_GFDL_SPEAR  \
# 0    10.5 1994-10-01  JAS 1995-08-15  0.980809            25.66215
# 1     9.5 1994-11-01  JAS 1995-08-15  0.994139            25.52513
# 2     8.5 1994-12-01  JAS 1995-08-15  0.986260            25.48767
# 3     7.5 1995-01-01  JAS 1995-08-15  0.687731            25.26264
# 4     6.5 1995-02-01  JAS 1995-08-15  0.702273            25.25708
# ..    ...        ...  ...        ...       ...                 ...
# 180   5.5 2018-04-01  ASO 2018-09-15  0.790188            26.28632
# 181   4.5 2018-05-01  ASO 2018-09-15  0.694985            26.27201
# 182   3.5 2018-06-01  ASO 2018-09-15  0.979141            26.61941
# 183   2.5 2018-07-01  ASO 2018-09-15  0.964408            27.05198
# 184   1.5 2018-08-01  ASO 2018-09-15  0.999787            27.09763
#
#      MEAN_SST_GFDL_SPEAR  ANOM_GFDL_SPEAR  OBS_NINO3.4_L3  \
# 0              26.115971        -0.453821       26.396667
# 1              26.142254        -0.617124       26.396667
# 2              26.135664        -0.647994       26.396667
# 3              26.245908        -0.983268       26.396667
# 4              26.230352        -0.973272       26.396667
# ..                   ...              ...             ...
# 180            26.208824         0.077496       27.250000
# 181            26.278687        -0.006677       27.250000
# 182            26.261756         0.357654       27.250000
# 183            26.396788         0.655192       27.250000
# 184            26.597937         0.499693       27.250000
#
#      MEAN_OBS_NINO3.4_L3  ANOM_OBS  VARIANCE3.4_L3
# 0              26.955667 -0.559000        0.576438
# 1              26.955667 -0.559000        0.576438
# 2              26.955667 -0.559000        0.576438
# 3              26.955667 -0.559000        0.576438
# 4              26.955667 -0.559000        0.576438
# ..                   ...       ...             ...
# 180            26.763333  0.486667        0.797956
# 181            26.763333  0.486667        0.797956
# 182            26.763333  0.486667        0.797956
# 183            26.763333  0.486667        0.797956
# 184            26.763333  0.486667        0.797956
#
# [185 rows x 12 columns]

# %%
gfdl_all_onset.describe()
# Out:
#                 L                            MON  \
# count  185.000000                            185
# mean     5.932432  2006-12-18 07:00:19.459459584
# min      1.500000            1991-01-01 00:00:00
# 25%      3.500000            2001-09-01 00:00:00
# 50%      5.500000            2007-03-01 00:00:00
# 75%      8.500000            2014-03-01 00:00:00
# max     10.500000            2020-07-01 00:00:00
# std      2.879279                            NaN
#
#                                  TAR        SESS  LDC_SST_GFDL_SPEAR  \
# count                            185  185.000000          185.000000
# mean   2007-06-15 11:40:32.432432384    0.327477           26.551587
# min              1991-06-15 00:00:00   -4.389310           24.688260
# 25%              2002-06-15 00:00:00    0.191347           25.967520
# 50%              2007-06-15 00:00:00    0.731160           26.554240
# 75%              2014-10-15 00:00:00    0.924580           27.125740
# max              2020-08-15 00:00:00    1.000000           28.068260
# std                              NaN    1.010250            0.729182
#
#        MEAN_SST_GFDL_SPEAR  ANOM_GFDL_SPEAR  OBS_NINO3.4_L3  \
# count           185.000000       185.000000      185.000000
# mean             26.610993        -0.059406       27.042523
# min              25.933564        -1.350825       26.060000
# 25%              26.221514        -0.392064       26.396667
# 50%              26.565858        -0.037889       27.180000
# 75%              26.974693         0.250501       27.350000
# max              27.778266         1.016450       28.460000
# std               0.470286         0.494599        0.724327
#
#        MEAN_OBS_NINO3.4_L3    ANOM_OBS  VARIANCE3.4_L3
# count           185.000000  185.000000      185.000000
# mean             27.118877   -0.076354        0.632031
# min              26.672667   -0.888333        0.256750
# 25%              26.763333   -0.559000        0.401165
# 50%              26.955667   -0.471111        0.576438
# 75%              27.291667    0.497444        0.797956
# max              27.826222    0.633778        1.304206
# std               0.390009    0.567640        0.341228

# %%
negative_count = (gfdl_all_onset['SESS'] < 0).sum()
negative_count
# Out:
# 44

# %%
(44/185)*100
# Out:
# 23.783783783783786

# %%
# Create a MultiIndex series from gfdl_stat
multi_index_stat = gfdl_stat.set_index(['L', 'SZN'])['MEAN_SST_GFDL_SPEAR']

# Map the MEAN_SST_GFDL_SPEAR values to the gfdl_all_onset dataframe
gfdl_all_onset['MEAN_SST_GFDL_SPEAR'] = gfdl_all_onset.set_index(['L', 'SZN']).index.map(multi_index_stat)

# Reset index to keep original structure
gfdl_all_onset.reset_index(drop=True, inplace=True)

#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_GFDL_SPEAR'] = gfdl_all_onset['LDC_SST_GFDL_SPEAR'] - gfdl_all_onset['MEAN_SST_GFDL_SPEAR']


# Create a MultiIndex series from gfdl_stat
multi_index_stat_two = monthly_obs.set_index(['SZN'])['NINO3.4_L3']
gfdl_all_onset['MEAN_OBS_NINO3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_two)
gfdl_all_onset.reset_index(drop=True, inplace=True)
#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_OBS'] = gfdl_all_onset['OBS_NINO3.4_L3'] - gfdl_all_onset['MEAN_OBS_NINO3.4_L3']


multi_index_stat_three = monthly_obs.set_index(['SZN'])['VARIANCE3.4_L3']
gfdl_all_onset['VARIANCE3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_three)
gfdl_all_onset.reset_index(drop=True, inplace=True)


gfdl_all_onset['SESS'] = 1-((gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])*(gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])/(gfdl_all_onset['VARIANCE3.4_L3']))


gfdl_all_onset = gfdl_all_onset[['L', 'MON', 'SZN','TAR','SESS','LDC_SST_GFDL_SPEAR','MEAN_SST_GFDL_SPEAR', 'ANOM_GFDL_SPEAR', 'OBS_NINO3.4_L3', 'MEAN_OBS_NINO3.4_L3', 'ANOM_OBS', 'VARIANCE3.4_L3']]

gfdl_all_onset
# Out:
#         L        MON  SZN        TAR      SESS  LDC_SST_GFDL_SPEAR  \
# 0    10.5 1994-10-01  JAS 1995-08-15  0.980809            25.66215
# 1     9.5 1994-11-01  JAS 1995-08-15  0.994139            25.52513
# 2     8.5 1994-12-01  JAS 1995-08-15  0.986260            25.48767
# 3     7.5 1995-01-01  JAS 1995-08-15  0.687731            25.26264
# 4     6.5 1995-02-01  JAS 1995-08-15  0.702273            25.25708
# ..    ...        ...  ...        ...       ...                 ...
# 180   5.5 2018-04-01  ASO 2018-09-15  0.790188            26.28632
# 181   4.5 2018-05-01  ASO 2018-09-15  0.694985            26.27201
# 182   3.5 2018-06-01  ASO 2018-09-15  0.979141            26.61941
# 183   2.5 2018-07-01  ASO 2018-09-15  0.964408            27.05198
# 184   1.5 2018-08-01  ASO 2018-09-15  0.999787            27.09763
#
#      MEAN_SST_GFDL_SPEAR  ANOM_GFDL_SPEAR  OBS_NINO3.4_L3  \
# 0              26.115971        -0.453821       26.396667
# 1              26.142254        -0.617124       26.396667
# 2              26.135664        -0.647994       26.396667
# 3              26.245908        -0.983268       26.396667
# 4              26.230352        -0.973272       26.396667
# ..                   ...              ...             ...
# 180            26.208824         0.077496       27.250000
# 181            26.278687        -0.006677       27.250000
# 182            26.261756         0.357654       27.250000
# 183            26.396788         0.655192       27.250000
# 184            26.597937         0.499693       27.250000
#
#      MEAN_OBS_NINO3.4_L3  ANOM_OBS  VARIANCE3.4_L3
# 0              26.955667 -0.559000        0.576438
# 1              26.955667 -0.559000        0.576438
# 2              26.955667 -0.559000        0.576438
# 3              26.955667 -0.559000        0.576438
# 4              26.955667 -0.559000        0.576438
# ..                   ...       ...             ...
# 180            26.763333  0.486667        0.797956
# 181            26.763333  0.486667        0.797956
# 182            26.763333  0.486667        0.797956
# 183            26.763333  0.486667        0.797956
# 184            26.763333  0.486667        0.797956
#
# [185 rows x 12 columns]

# %%
# Map the MEAN_SST_GFDL_SPEAR values to the gfdl_all_onset dataframe
gfdl_all_onset['MEAN_SST_GFDL_SPEAR'] = gfdl_all_onset.set_index(['L', 'SZN']).index.map(multi_index_stat)

# Reset index to keep original structure
gfdl_all_onset.reset_index(drop=True, inplace=True)

#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_GFDL_SPEAR'] = gfdl_all_onset['LDC_SST_GFDL_SPEAR'] - gfdl_all_onset['MEAN_SST_GFDL_SPEAR']


# Create a MultiIndex series from gfdl_stat
multi_index_stat_two = monthly_obs.set_index(['SZN'])['NINO3.4_L3']
gfdl_all_onset['MEAN_OBS_NINO3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_two)
gfdl_all_onset.reset_index(drop=True, inplace=True)
#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_OBS'] = gfdl_all_onset['OBS_NINO3.4_L3'] - gfdl_all_onset['MEAN_OBS_NINO3.4_L3']


multi_index_stat_three = monthly_obs.set_index(['SZN'])['VARIANCE3.4_L3']
gfdl_all_onset['VARIANCE3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_three)
gfdl_all_onset.reset_index(drop=True, inplace=True)


gfdl_all_onset['SESS'] = 1-((gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])*(gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])/(gfdl_all_onset['VARIANCE3.4_L3']))


gfdl_all_onset = gfdl_all_onset[['L', 'MON', 'SZN','TAR','SESS','LDC_SST_GFDL_SPEAR','MEAN_SST_GFDL_SPEAR', 'ANOM_GFDL_SPEAR', 'OBS_NINO3.4_L3', 'MEAN_OBS_NINO3.4_L3', 'ANOM_OBS', 'VARIANCE3.4_L3']]

gfdl_all_onset
# Out:
#         L        MON  SZN        TAR      SESS  LDC_SST_GFDL_SPEAR  \
# 0    10.5 1994-10-01  JAS 1995-08-15  0.980809            25.66215
# 1     9.5 1994-11-01  JAS 1995-08-15  0.994139            25.52513
# 2     8.5 1994-12-01  JAS 1995-08-15  0.986260            25.48767
# 3     7.5 1995-01-01  JAS 1995-08-15  0.687731            25.26264
# 4     6.5 1995-02-01  JAS 1995-08-15  0.702273            25.25708
# ..    ...        ...  ...        ...       ...                 ...
# 180   5.5 2018-04-01  ASO 2018-09-15  0.790188            26.28632
# 181   4.5 2018-05-01  ASO 2018-09-15  0.694985            26.27201
# 182   3.5 2018-06-01  ASO 2018-09-15  0.979141            26.61941
# 183   2.5 2018-07-01  ASO 2018-09-15  0.964408            27.05198
# 184   1.5 2018-08-01  ASO 2018-09-15  0.999787            27.09763
#
#      MEAN_SST_GFDL_SPEAR  ANOM_GFDL_SPEAR  OBS_NINO3.4_L3  \
# 0              26.115971        -0.453821       26.396667
# 1              26.142254        -0.617124       26.396667
# 2              26.135664        -0.647994       26.396667
# 3              26.245908        -0.983268       26.396667
# 4              26.230352        -0.973272       26.396667
# ..                   ...              ...             ...
# 180            26.208824         0.077496       27.250000
# 181            26.278687        -0.006677       27.250000
# 182            26.261756         0.357654       27.250000
# 183            26.396788         0.655192       27.250000
# 184            26.597937         0.499693       27.250000
#
#      MEAN_OBS_NINO3.4_L3  ANOM_OBS  VARIANCE3.4_L3
# 0              26.955667 -0.559000        0.576438
# 1              26.955667 -0.559000        0.576438
# 2              26.955667 -0.559000        0.576438
# 3              26.955667 -0.559000        0.576438
# 4              26.955667 -0.559000        0.576438
# ..                   ...       ...             ...
# 180            26.763333  0.486667        0.797956
# 181            26.763333  0.486667        0.797956
# 182            26.763333  0.486667        0.797956
# 183            26.763333  0.486667        0.797956
# 184            26.763333  0.486667        0.797956
#
# [185 rows x 12 columns]

# %%
# Map the MEAN_SST_GFDL_SPEAR values to the gfdl_all_onset dataframe
gfdl_all_onset['MEAN_SST_GFDL_SPEAR'] = gfdl_all_onset.set_index(['L', 'SZN']).index.map(multi_index_stat)

# Reset index to keep original structure
gfdl_all_onset.reset_index(drop=True, inplace=True)

#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_GFDL_SPEAR'] = gfdl_all_onset['LDC_SST_GFDL_SPEAR'] - gfdl_all_onset['MEAN_SST_GFDL_SPEAR']


# Create a MultiIndex series from gfdl_stat
multi_index_stat_two = monthly_obs.set_index(['SZN'])['NINO3.4_L3']
gfdl_all_onset['MEAN_OBS_NINO3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_two)
gfdl_all_onset.reset_index(drop=True, inplace=True)
#Calculate Forecasted Anomaly
gfdl_all_onset['ANOM_OBS'] = gfdl_all_onset['OBS_NINO3.4_L3'] - gfdl_all_onset['MEAN_OBS_NINO3.4_L3']


multi_index_stat_three = monthly_obs.set_index(['SZN'])['VARIANCE3.4_L3']
gfdl_all_onset['VARIANCE3.4_L3'] = gfdl_all_onset.set_index(['SZN']).index.map(multi_index_stat_three)
gfdl_all_onset.reset_index(drop=True, inplace=True)


gfdl_all_onset['SESS'] = 1-((gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])*(gfdl_all_onset['ANOM_GFDL_SPEAR']-gfdl_all_onset['ANOM_OBS'])/(gfdl_all_onset['VARIANCE3.4_L3']))


gfdl_all_onset = gfdl_all_onset[['L', 'MON', 'SZN','TAR','SESS','LDC_SST_GFDL_SPEAR','MEAN_SST_GFDL_SPEAR', 'ANOM_GFDL_SPEAR', 'OBS_NINO3.4_L3', 'MEAN_OBS_NINO3.4_L3', 'ANOM_OBS', 'VARIANCE3.4_L3']]

gfdl_all_onset
# Out:
#         L        MON  SZN        TAR      SESS  LDC_SST_GFDL_SPEAR  \
# 0    10.5 1994-10-01  JAS 1995-08-15  0.980809            25.66215
# 1     9.5 1994-11-01  JAS 1995-08-15  0.994139            25.52513
# 2     8.5 1994-12-01  JAS 1995-08-15  0.986260            25.48767
# 3     7.5 1995-01-01  JAS 1995-08-15  0.687731            25.26264
# 4     6.5 1995-02-01  JAS 1995-08-15  0.702273            25.25708
# ..    ...        ...  ...        ...       ...                 ...
# 180   5.5 2018-04-01  ASO 2018-09-15  0.790188            26.28632
# 181   4.5 2018-05-01  ASO 2018-09-15  0.694985            26.27201
# 182   3.5 2018-06-01  ASO 2018-09-15  0.979141            26.61941
# 183   2.5 2018-07-01  ASO 2018-09-15  0.964408            27.05198
# 184   1.5 2018-08-01  ASO 2018-09-15  0.999787            27.09763
#
#      MEAN_SST_GFDL_SPEAR  ANOM_GFDL_SPEAR  OBS_NINO3.4_L3  \
# 0              26.115971        -0.453821       26.396667
# 1              26.142254        -0.617124       26.396667
# 2              26.135664        -0.647994       26.396667
# 3              26.245908        -0.983268       26.396667
# 4              26.230352        -0.973272       26.396667
# ..                   ...              ...             ...
# 180            26.208824         0.077496       27.250000
# 181            26.278687        -0.006677       27.250000
# 182            26.261756         0.357654       27.250000
# 183            26.396788         0.655192       27.250000
# 184            26.597937         0.499693       27.250000
#
#      MEAN_OBS_NINO3.4_L3  ANOM_OBS  VARIANCE3.4_L3
# 0              26.955667 -0.559000        0.576438
# 1              26.955667 -0.559000        0.576438
# 2              26.955667 -0.559000        0.576438
# 3              26.955667 -0.559000        0.576438
# 4              26.955667 -0.559000        0.576438
# ..                   ...       ...             ...
# 180            26.763333  0.486667        0.797956
# 181            26.763333  0.486667        0.797956
# 182            26.763333  0.486667        0.797956
# 183            26.763333  0.486667        0.797956
# 184            26.763333  0.486667        0.797956
#
# [185 rows x 12 columns]

# %%
def all_gfdl_bias_visualizer():
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['Arial']
    plt.figure(figsize=(13, 7))

    
    #plt.plot(gfdl_all_onset_mean['L']-1.5, gfdl_all_onset_mean['BIAS_ABS'], marker='o',markersize=6, linewidth=2, linestyle='-', color='blue', label = 'Mean', zorder=2)
    sns.boxplot(x='L', y='SESS', data=gfdl_all_onset, color = 'skyblue', zorder=1)
    #sns.scatterplot(x='L', y='BIAS', data=gfdl_all_onset, color = 'black', zorder=2)
    
    # Customize the plot
    plt.title(f'Distribution of Cold Phase SESS, GFDL-SPEAR', size = 24)
    plt.xlabel('Lead Time', size = 20)
    plt.ylabel('SST (°C)', size = 20)
    xticks_labels = gfdl_all_onset['L'] - 1
    plt.xticks(size = 20)
    plt.yticks(size = 20)
    plt.grid(True)
    #plt.legend(frameon=False)
    plt.ylim(ymin=-5, ymax = 2)
    #plt.savefig(f'../Plots/Obs/all_distribution_and_mean.png', format='png')
    # Show the plot
    plt.show() 


all_gfdl_bias_visualizer()

# %%
def all_gfdl_bias_visualizer():
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['Arial']
    plt.figure(figsize=(13, 7))

    
    #plt.plot(gfdl_all_onset_mean['L']-1.5, gfdl_all_onset_mean['BIAS_ABS'], marker='o',markersize=6, linewidth=2, linestyle='-', color='blue', label = 'Mean', zorder=2)
    sns.boxplot(x='L', y='SESS', data=gfdl_all_onset, color = 'salmon', zorder=1)
    #sns.scatterplot(x='L', y='BIAS', data=gfdl_all_onset, color = 'black', zorder=2)
    
    # Customize the plot
    plt.title(f'Distribution of Warm Phase SESS, GFDL-SPEAR', size = 24)
    plt.xlabel('Lead Time', size = 20)
    plt.ylabel('SST (°C)', size = 20)
    xticks_labels = gfdl_all_onset['L'] - 1
    plt.xticks(size = 20)
    plt.yticks(size = 20)
    plt.grid(True)
    #plt.legend(frameon=False)
    plt.ylim(ymin=-5, ymax = 2)
    #plt.savefig(f'../Plots/Obs/all_distribution_and_mean.png', format='png')
    # Show the plot
    plt.show() 


all_gfdl_bias_visualizer()

# %%
def all_and_all_gfdl_bias_visualizer():
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['Arial']
    plt.figure(figsize=(13, 7))

    
    #plt.plot(gfdl_all_onset_mean['L']-1.5, gfdl_all_onset_mean['BIAS_ABS'], marker='o',markersize=6, linewidth=2, linestyle='-', color='blue', label = 'Mean', zorder=2)
    sns.boxplot(x='L', y='SESS', data=gfdl_all_onset, color = 'skyblue', zorder=1)
    sns.boxplot(x='L', y='SESS', data=gfdl_all_onset, color = 'salmon', zorder=1)
    #sns.scatterplot(x='L', y='BIAS', data=gfdl_all_onset, color = 'black', zorder=2)
    
    # Customize the plot
    plt.title(f'Distribution of Cold Phase SESS, GFDL-SPEAR', size = 24)
    plt.xlabel('Lead Time', size = 20)
    plt.ylabel('SST (°C)', size = 20)
    xticks_labels = gfdl_all_onset['L'] - 1
    plt.xticks(size = 20)
    plt.yticks(size = 20)
    plt.grid(True)
    #plt.legend(frameon=False)
    plt.ylim(ymin=-5, ymax = 2)
    #plt.savefig(f'../Plots/Obs/all_distribution_and_mean.png', format='png')
    # Show the plot
    plt.show() 


all_and_all_gfdl_bias_visualizer()

# %%
from matplotlib.colors import LogNorm
def all_gfdl_bias_visualizer():
    
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.sans-serif'] = ['Arial']
    plt.figure(figsize=(13, 7))

    
    plt.plot(gfdl_all_onset['L'], gfdl_all_onset['SESS'], marker='o',markersize=6, linewidth=2, linestyle='-', color='blue', label = 'Mean', zorder=2)
    #sns.boxplot(x='L', y='SESS', data=gfdl_all_onset, color = 'salmon', zorder=1)
    #sns.scatterplot(x='L', y='BIAS', data=gfdl_all_onset, color = 'black', zorder=2)
    
    # Customize the plot
    plt.title(f'Distribution of Warm Phase SESS, GFDL-SPEAR', size = 24)
    plt.xlabel('Lead Time', size = 20)
    plt.ylabel('SST (°C)', size = 20)
    xticks_labels = gfdl_all_onset['L'] - 1
    plt.xticks(size = 20)
    plt.yticks(size = 20)
    plt.grid(True)
    #plt.legend(frameon=False)
    plt.ylim(ymin=-5, ymax = 2)
    #plt.savefig(f'../Plots/Obs/all_distribution_and_mean.png', format='png')
    # Show the plot
    plt.show() 


all_gfdl_bias_visualizer()

# %%
gfdl_all_onset['TAR'] = pd.to_datetime(gfdl_all_onset['TAR'])

# Pivot the dataframe
gfdl_all_mesh = gfdl_all_onset.pivot(index='L', columns='TAR', values='SESS')


gfdl_warm_onset['TAR'] = pd.to_datetime(gfdl_warm_onset['TAR'])

# Pivot the dataframe
gfdl_warm_mesh = gfdl_all_onset.pivot(index='L', columns='TAR', values='SESS')


gfdl_all_onset['TAR'] = pd.to_datetime(gfdl_all_onset['TAR'])

# Pivot the dataframe
gfdl_all_mesh = gfdl_all_onset.pivot(index='L', columns='TAR', values='SESS')

gfdl_all_mesh
# Out:
# TAR   1991-06-15  1994-09-15  1995-08-15  1997-05-15  1998-07-15  2002-06-15  \
# L
# 1.5    -0.035988    0.114595    0.900362   -0.197044    0.475743    0.703228
# 2.5    -2.762770   -0.429391    0.941211    0.576188    0.993209    0.671343
# 3.5    -0.967493    0.345708   -0.087692    0.395649    0.958229    0.811771
# 4.5    -0.974045   -0.055698    0.940330    0.427843    1.000000    0.924580
# 5.5    -0.970701   -0.200460    0.923899    0.255088    0.701596    0.845844
# 6.5          NaN   -1.065769    0.702273   -0.630793   -0.026442    0.461392
# 7.5          NaN   -0.949117    0.687731   -0.130394    0.191347    0.845705
# 8.5          NaN   -1.980760    0.986260   -0.460570    0.417038    0.998734
# 9.5          NaN   -2.802345    0.994139   -2.056245    0.827232    0.913663
# 10.5         NaN   -3.278621    0.980809   -3.483635    0.586157    0.858431
#
# TAR   2004-07-15  2005-11-15  2006-09-15  2007-06-15  2008-11-15  2009-07-15  \
# L
# 1.5     0.452724    0.880081    0.836826    0.898817    0.866632    0.880558
# 2.5     0.456741    0.943500    0.990610    0.595862    0.894121    0.999227
# 3.5     0.824644    0.909613    0.766859    0.731160    0.925807    0.971371
# 4.5     0.725790    0.998769    0.958780    0.734858    0.951767    0.870317
# 5.5     0.688538    0.981378    0.606789    0.612591    0.713254    0.861450
# 6.5     0.603880    0.963436    0.992905    0.244616    0.952131    0.972038
# 7.5     0.377923    0.958462    0.839710    0.565331    0.969075    0.936869
# 8.5     0.805886    0.997576    0.475933   -0.678996    0.995852    0.794921
# 9.5     0.736211    0.795424    0.418857   -0.632385    0.986779    0.788262
# 10.5    0.885976    0.554003    0.916369    0.606703    0.879428    0.604429
#
# TAR   2010-06-15  2011-07-15  2014-10-15  2016-08-15  2017-10-15  2018-09-15  \
# L
# 1.5    -0.829393    0.113161    0.997620    0.848089    0.999088    0.999787
# 2.5     0.419184   -0.329169    0.831275    0.988979    0.785372    0.964408
# 3.5     0.902984   -0.915724    0.997648    0.731624    0.742956    0.979141
# 4.5     0.712865   -0.241469    0.783718    0.667983    0.488700    0.694985
# 5.5    -0.057178   -0.946659    0.745304    0.972971   -0.051939    0.790188
# 6.5    -1.113882   -0.282485    0.950037    0.998371   -0.692445    0.655930
# 7.5    -2.712769   -0.325898    0.997763    0.984539   -1.522506    0.646632
# 8.5    -3.217105    0.650284    0.822019    0.977455   -0.425805    0.616075
# 9.5    -4.347406    0.751544    0.862352    0.765579   -0.191585    0.281440
# 10.5   -4.389310    0.982612    0.964572    0.305893    0.229423    0.550301
#
# TAR   2020-08-15
# L
# 1.5     0.977478
# 2.5     0.997667
# 3.5     0.893363
# 4.5     0.990822
# 5.5     0.895971
# 6.5     0.911712
# 7.5     0.562480
# 8.5    -0.755400
# 9.5    -0.013288
# 10.5   -0.084042

# %%
"""from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
np.random.seed(19680801)

Z = np.random.rand(10, 84)
x = gfdl_all_onset['TAR']  
y = np.arange(0, 11, 1)  

c = plt.pcolormesh(x, y, Z)
plt.colorbar(c)
plt.show()
"""

from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
np.random.seed(19680801)

Z = gfdl_all_mesh
y = np.arange(0, 11, 1)  
x = np.arange(400.5, 410.5, 1)  

c = plt.pcolormesh(x, y, Z)
plt.colorbar(c)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[196], line 22
#      19 y = np.arange(0, 11, 1)
#      20 x = np.arange(400.5, 410.5, 1)
# ---> 22 c = plt.pcolormesh(x, y, Z)
#      23 plt.colorbar(c)
#      24 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:3493, in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    3480 @_copy_docstring_and_deprecators(Axes.pcolormesh)
#    3481 def pcolormesh(
#    3482     *args: ArrayLike,
#    (...)
#    3491     **kwargs,
#    3492 ) -> QuadMesh:
# -> 3493     __ret = gca().pcolormesh(
#    3494         *args,
#    3495         alpha=alpha,
#    3496         norm=norm,
#    3497         cmap=cmap,
#    3498         vmin=vmin,
#    3499         vmax=vmax,
#    3500         shading=shading,
#    3501         antialiased=antialiased,
#    3502         **({"data": data} if data is not None else {}),
#    3503         **kwargs,
#    3504     )
#    3505     sci(__ret)
#    3506     return __ret
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6292, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6289 shading = shading.lower()
#    6290 kwargs.setdefault('edgecolors', 'none')
# -> 6292 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6293                                     shading=shading, kwargs=kwargs)
#    6294 coords = np.stack([X, Y], axis=-1)
#    6296 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py:5839, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    5837 if shading == 'flat':
#    5838     if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 5839         raise TypeError(f"Dimensions of C {C.shape} should"
#    5840                         f" be one smaller than X({Nx}) and Y({Ny})"
#    5841                         f" while using shading='flat'"
#    5842                         f" see help({funcname})")
#    5843 else:    # ['nearest', 'gouraud']:
#    5844     if (Nx, Ny) != (ncols, nrows):
#
# TypeError: Dimensions of C (10, 19) should be one smaller than X(10) and Y(11) while using shading='flat' see help(pcolormesh)

# %%
# Ensure there are no NaN values or handle them appropriately
gfdl_cold_mesh = gfdl_cold_mesh.fillna(np.nan)

# Extract the x and y values
x = gfdl_cold_mesh.columns.values  # Lead times (L)
y = gfdl_cold_mesh.index.values    # Target times (TAR)

# Ensure the Z values match the shape required for pcolormesh
Z = gfdl_cold_mesh.values

# Create the meshgrid
x_mesh, y_mesh = np.meshgrid(x, y)

# Plot using pcolormesh
plt.figure(figsize=(12, 6))
c = plt.pcolormesh(x_mesh, y_mesh, Z, cmap='viridis', shading='auto')

# Add color bar
plt.colorbar(c, label='SESS')

# Add labels and title
plt.ylabel('Lead Time (L)')
plt.xlabel('Target Time (TAR)')
plt.title('Pseudocolor plot of SESS with respect to Lead Time and Target Time, GFDL Warm Events')
plt.xticks(ticks=x, rotation=45)

# Show plot
plt.show()

# %%
# Ensure there are no NaN values or handle them appropriately
gfdl_cold_mesh = gfdl_cold_mesh.fillna(np.nan)

# Extract the x and y values
x = gfdl_cold_mesh.columns.values  # Lead times (L)
y = gfdl_cold_mesh.index.values    # Target times (TAR)

# Ensure the Z values match the shape required for pcolormesh
Z = gfdl_cold_mesh.values

# Create the meshgrid
x_mesh, y_mesh = np.meshgrid(x, y)

# Plot using pcolormesh
plt.figure(figsize=(12, 6))
c = plt.pcolormesh(x_mesh, y_mesh, Z, cmap='viridis', shading='auto')

# Add color bar
plt.colorbar(c, label='SESS')

# Add labels and title
plt.ylabel('Lead Time (L)')
plt.xlabel('Target Time (TAR)')
plt.title('Pseudocolor plot of SESS with respect to Lead Time and Target Time, GFDL Warm Events')
plt.xticks(ticks=x, rotation=45)

# Show plot
plt.show()
